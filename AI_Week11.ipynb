# %%
pip install youtube-search
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting youtube-search
#   Downloading youtube_search-2.1.2-py3-none-any.whl (3.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from youtube-search) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->youtube-search) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->youtube-search) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->youtube-search) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->youtube-search) (2.0.12)
# Installing collected packages: youtube-search
# Successfully installed youtube-search-2.1.2

# %%
from youtube_search import YoutubeSearch
import webbrowser
mysong=input('nhap ten bai hat')
result=YoutubeSearch(mysong,max_results=10).to_dict()
print(result)
# Out:
# nhap ten bai hathello
# [{'id': 'YQHsXMglC9A', 'thumbnails': ['https://i.ytimg.com/vi/YQHsXMglC9A/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLAHnhWEMlSYbwVzv7HE1YaH8_8RrQ', 'https://i.ytimg.com/vi/YQHsXMglC9A/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLCdLcY7Ni9L3AP5ZQ7RDGNaIo6H3g'], 'title': 'Adele - Hello (Official Music Video)', 'long_desc': None, 'channel': 'Adele', 'duration': '6:07', 'views': '3.063.470.948 weergaven', 'publish_time': '7 jaar geleden', 'url_suffix': '/watch?v=YQHsXMglC9A&pp=ygUFaGVsbG8%3D'}, {'id': 'be12BC5pQLE', 'thumbnails': ['https://i.ytimg.com/vi/be12BC5pQLE/hqdefault.jpg?sqp=-oaymwE9COADEI4CSFryq4qpAy8IARUAAAAAGAElAADIQj0AgKJDeAHwAQH4Af4JgALQBYoCDAgAEAEYZSBlKGUwDw==&rs=AOn4CLABjrvbrFfjq5UtE5FVpJBlGW4miA'], 'title': 'Adele - Hello (Lyrics)', 'long_desc': None, 'channel': 'Aqua Lyrics', 'duration': '4:57', 'views': '17.278.565 weergaven', 'publish_time': '2 jaar geleden', 'url_suffix': '/watch?v=be12BC5pQLE&pp=ygUFaGVsbG8%3D'}, {'id': 'kK42LZqO0wA', 'thumbnails': ['https://i.ytimg.com/vi/kK42LZqO0wA/hqdefault.jpg?sqp=-oaymwEjCOADEI4CSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLAD7ZYW5mh8BHNzr1bjUvZsSDStLw'], 'title': 'Martin Solveig & Dragonette - Hello (Official Short Video Version HD)', 'long_desc': None, 'channel': 'Kontor.TV', 'duration': '4:13', 'views': '106.625.690 weergaven', 'publish_time': '12 jaar geleden', 'url_suffix': '/watch?v=kK42LZqO0wA&pp=ygUFaGVsbG8%3D'}, {'id': 'mHONNcZbwDY', 'thumbnails': ['https://i.ytimg.com/vi/mHONNcZbwDY/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLCQ0hGFDaq3Y0XrrKUKMXjeZOq8Xg', 'https://i.ytimg.com/vi/mHONNcZbwDY/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLClfqZQqqf4y5Ha1FsD2UhgtOIzkQ'], 'title': 'Lionel Richie - Hello (Official Music Video)', 'long_desc': None, 'channel': 'lionelrichie', 'duration': '5:27', 'views': '70.186.226 weergaven', 'publish_time': '2 jaar geleden', 'url_suffix': '/watch?v=mHONNcZbwDY&pp=ygUFaGVsbG8%3D'}, {'id': 'bnVUHWCynig', 'thumbnails': ['https://i.ytimg.com/vi/bnVUHWCynig/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDGZH-faaS4SKTWqqfeqy20wLGhHA', 'https://i.ytimg.com/vi/bnVUHWCynig/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLBKCnStxA9mXlgTMB6LtBhRP7wpzA'], 'title': 'Beyoncé - Halo', 'long_desc': None, 'channel': 'Beyoncé', 'duration': '3:45', 'views': '1.388.079.125 weergaven', 'publish_time': '13 jaar geleden', 'url_suffix': '/watch?v=bnVUHWCynig&pp=ygUFaGVsbG8%3D'}, {'id': 'fazMSCZg-mw', 'thumbnails': ['https://i.ytimg.com/vi/fazMSCZg-mw/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLD83G1Qgoz32DrPPGsqcpin1Y_w7A', 'https://i.ytimg.com/vi/fazMSCZg-mw/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLB-67_1uw3KPkOv_e_9a3Y-mhekgQ'], 'title': 'Pop Smoke - Hello (Audio) ft. A Boogie wit da Hoodie', 'long_desc': None, 'channel': 'POP SMOKE', 'duration': '3:12', 'views': '148.982.160 weergaven', 'publish_time': '2 jaar geleden', 'url_suffix': '/watch?v=fazMSCZg-mw&pp=ygUFaGVsbG8%3D'}, {'id': 'aPd9exmH17o', 'thumbnails': ['https://i.ytimg.com/vi/aPd9exmH17o/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLAgHx-petEMk0WUTfW8W7BfRDb97g', 'https://i.ytimg.com/vi/aPd9exmH17o/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLA4529YsHX2M_OA5JD1V4q9vPhgeA'], 'title': 'TREASURE - ‘HELLO’ M/V', 'long_desc': None, 'channel': 'TREASURE (트레저)', 'duration': '3:06', 'views': '68.334.112 weergaven', 'publish_time': '6 maanden geleden', 'url_suffix': '/watch?v=aPd9exmH17o&pp=ygUFaGVsbG8%3D'}, {'id': 't071Wm45qWM', 'thumbnails': ['https://i.ytimg.com/vi/t071Wm45qWM/hq720.jpg?sqp=-oaymwE9COgCEMoBSFryq4qpAy8IARUAAAAAGAElAADIQj0AgKJDeAHwAQH4Af4JgALQBYoCDAgAEAEYZSBZKEgwDw==&rs=AOn4CLCaPSDHi6ETebCLYFLScHzTtV8yuA', 'https://i.ytimg.com/vi/t071Wm45qWM/hq720.jpg?sqp=-oaymwExCNAFEJQDSFryq4qpAyMIARUAAIhCGAHwAQH4Af4JgALQBYoCDAg ...

# %%
print(result[0]['url_suffix'])
url='http://www.youtube.com'+result[0]['url_suffix']
print(url)
# Out:
# /watch?v=YQHsXMglC9A&pp=ygUFaGVsbG8%3D
# http://www.youtube.com/watch?v=YQHsXMglC9A&pp=ygUFaGVsbG8%3D

# %%
for i in range(10):
  print(result[i]['title'])
  print(result[i]['url_suffix'])
  url='http://www.youtube.com'+result[i]['url_suffix']
  print(url)
# Out:
# Adele - Hello (Official Music Video)
# /watch?v=YQHsXMglC9A&pp=ygUFaGVsbG8%3D
# http://www.youtube.com/watch?v=YQHsXMglC9A&pp=ygUFaGVsbG8%3D
# Adele - Hello (Lyrics)
# /watch?v=be12BC5pQLE&pp=ygUFaGVsbG8%3D
# http://www.youtube.com/watch?v=be12BC5pQLE&pp=ygUFaGVsbG8%3D
# Martin Solveig & Dragonette - Hello (Official Short Video Version HD)
# /watch?v=kK42LZqO0wA&pp=ygUFaGVsbG8%3D
# http://www.youtube.com/watch?v=kK42LZqO0wA&pp=ygUFaGVsbG8%3D
# Lionel Richie - Hello (Official Music Video)
# /watch?v=mHONNcZbwDY&pp=ygUFaGVsbG8%3D
# http://www.youtube.com/watch?v=mHONNcZbwDY&pp=ygUFaGVsbG8%3D
# Beyoncé - Halo
# /watch?v=bnVUHWCynig&pp=ygUFaGVsbG8%3D
# http://www.youtube.com/watch?v=bnVUHWCynig&pp=ygUFaGVsbG8%3D
# TREASURE - ‘HELLO’ M/V
# /watch?v=aPd9exmH17o&pp=ygUFaGVsbG8%3D
# http://www.youtube.com/watch?v=aPd9exmH17o&pp=ygUFaGVsbG8%3D
# Pop Smoke - Hello (Audio) ft. A Boogie wit da Hoodie
# /watch?v=fazMSCZg-mw&pp=ygUFaGVsbG8%3D
# http://www.youtube.com/watch?v=fazMSCZg-mw&pp=ygUFaGVsbG8%3D
# Conkarah & Rosie Delmah - Hello (Reggae Cover) [Official Video]
# /watch?v=t071Wm45qWM&pp=ygUFaGVsbG8%3D
# http://www.youtube.com/watch?v=t071Wm45qWM&pp=ygUFaGVsbG8%3D
# Minidisco Hello! | Team4Animation
# /watch?v=lj6rzlSNqF8&pp=ygUFaGVsbG8%3D
# http://www.youtube.com/watch?v=lj6rzlSNqF8&pp=ygUFaGVsbG8%3D
# Martin Solveig - Hello
# /watch?v=jNm_wrWquPs&pp=ygUFaGVsbG8%3D
# http://www.youtube.com/watch?v=jNm_wrWquPs&pp=ygUFaGVsbG8%3D

# %%
pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.9/dist-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.9/dist-packages (from openpyxl) (1.1.0)

# %%
from openpyxl import Workbook
data=Workbook()
sheet=data.active
mysong=input('xin moi bạn chọn tên bài hát:')
print(mysong)
result=YoutubeSearch(mysong,max_results=10).to_dict()
print(result)
for i in range(10):
  print(result[i]['title'])
  print(result[i]['url_suffix'])
  url='http://www.youtube.com'+result[i]['url_suffix']
  print(url)
  sheet['A'+str(i+1)]=i+1
  sheet['B'+str(i+1)]=result[i]['title']
  sheet['C'+str(i+1)]=result[i]['url_suffix']
  sheet['D'+str(i+1)]=result[i]['views']
  #webbrower.open(url)
data.save('UTE.xlsx')
# Out:
# xin moi bạn chọn tên bài hát:Hello
# Hello
# [{'id': 'YQHsXMglC9A', 'thumbnails': ['https://i.ytimg.com/vi/YQHsXMglC9A/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLAHnhWEMlSYbwVzv7HE1YaH8_8RrQ', 'https://i.ytimg.com/vi/YQHsXMglC9A/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLCdLcY7Ni9L3AP5ZQ7RDGNaIo6H3g'], 'title': 'Adele - Hello (Official Music Video)', 'long_desc': None, 'channel': 'Adele', 'duration': '6:07', 'views': '3.063.473.569 weergaven', 'publish_time': '7 jaar geleden', 'url_suffix': '/watch?v=YQHsXMglC9A&pp=ygUFSGVsbG8%3D'}, {'id': 'be12BC5pQLE', 'thumbnails': ['https://i.ytimg.com/vi/be12BC5pQLE/hqdefault.jpg?sqp=-oaymwE9COADEI4CSFryq4qpAy8IARUAAAAAGAElAADIQj0AgKJDeAHwAQH4Af4JgALQBYoCDAgAEAEYZSBlKGUwDw==&rs=AOn4CLABjrvbrFfjq5UtE5FVpJBlGW4miA'], 'title': 'Adele - Hello (Lyrics)', 'long_desc': None, 'channel': 'Aqua Lyrics', 'duration': '4:57', 'views': '17.278.850 weergaven', 'publish_time': '2 jaar geleden', 'url_suffix': '/watch?v=be12BC5pQLE&pp=ygUFSGVsbG8%3D'}, {'id': 'mHONNcZbwDY', 'thumbnails': ['https://i.ytimg.com/vi/mHONNcZbwDY/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLCQ0hGFDaq3Y0XrrKUKMXjeZOq8Xg', 'https://i.ytimg.com/vi/mHONNcZbwDY/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLClfqZQqqf4y5Ha1FsD2UhgtOIzkQ'], 'title': 'Lionel Richie - Hello (Official Music Video)', 'long_desc': None, 'channel': 'lionelrichie', 'duration': '5:27', 'views': '70.187.263 weergaven', 'publish_time': '2 jaar geleden', 'url_suffix': '/watch?v=mHONNcZbwDY&pp=ygUFSGVsbG8%3D'}, {'id': 'tVlcKp3bWH8', 'thumbnails': ['https://i.ytimg.com/vi/tVlcKp3bWH8/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDb6gni2Qod-J8eYc-jk3R2imAACg', 'https://i.ytimg.com/vi/tVlcKp3bWH8/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDaLauLkdNEgIG-CacnuQLfMgiWJA'], 'title': 'Hello! | Super Simple Songs', 'long_desc': None, 'channel': 'Super Simple Songs - Kids Songs', 'duration': '1:19', 'views': '123.079.845 weergaven', 'publish_time': '8 jaar geleden', 'url_suffix': '/watch?v=tVlcKp3bWH8&pp=ygUFSGVsbG8%3D'}, {'id': 'Axx9IMdL4jc', 'thumbnails': ['https://i.ytimg.com/vi/Axx9IMdL4jc/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLCjxA0aYUZD57YKk5-SjXUH5wgn5Q', 'https://i.ytimg.com/vi/Axx9IMdL4jc/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDfVZZdxxy4QVaZs7xgyn_587s3og'], 'title': 'HELLO -  LIONEL RICHIE lyrics (HD)', 'long_desc': None, 'channel': 'Bluerose Skansen', 'duration': '4:07', 'views': '4.162.058 weergaven', 'publish_time': '2 jaar geleden', 'url_suffix': '/watch?v=Axx9IMdL4jc&pp=ygUFSGVsbG8%3D'}, {'id': 'kK42LZqO0wA', 'thumbnails': ['https://i.ytimg.com/vi/kK42LZqO0wA/hqdefault.jpg?sqp=-oaymwEjCOADEI4CSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLAD7ZYW5mh8BHNzr1bjUvZsSDStLw'], 'title': 'Martin Solveig & Dragonette - Hello (Official Short Video Version HD)', 'long_desc': None, 'channel': 'Kontor.TV', 'duration': '4:13', 'views': '106.625.880 weergaven', 'publish_time': '12 jaar geleden', 'url_suffix': '/watch?v=kK42LZqO0wA&pp=ygUFSGVsbG8%3D'}, {'id': 'fazMSCZg-mw', 'thumbnails': ['https://i.ytimg.com/vi/fazMSCZg-mw/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLD83G1Qgoz32DrPPGsqcpin1Y_w7A', 'https://i.ytimg.com/vi/fazMSCZg-mw/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLB-67_1uw3KPkOv_e_9a3Y-mhekgQ'], 'title': 'Pop Smoke - Hello (Audio) ft. A Boogie wit da Hoodie', 'long_desc': None, 'channel': 'POP SMOKE', 'duration': '3:12', 'views': '148.982.921 weergaven', 'publish_time': '2 jaar geleden', 'url_suffix': '/watch?v=fazMSCZg-mw&pp=ygUFSGVsbG8%3D'}, {'id': 'aPd9exmH17o', 'thumbnails': ['https://i.ytimg.com/vi/aPd9exmH17o/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLAgHx-petEMk0WUTfW8W7BfRDb97g', 'https://i.ytimg.com/vi/aPd9exmH17o/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLA ...
# Adele - Hello (Official Music Video)
# /watch?v=YQHsXMglC9A&pp=ygUFSGVsbG8%3D
# http://www.youtube.com/watch?v=YQHsXMglC9A&pp=ygUFSGVsbG8%3D
# Adele - Hello (Lyrics)
# /watch?v=be12BC5pQLE&pp=ygUFSGVsbG8%3D
# http://www.youtube.com/watch?v=be12BC5pQLE&pp=ygUFSGVsbG8%3D
# Lionel Richie - Hello (Official Music Video)
# /watch?v=mHONNcZbwDY&pp=ygUFSGVsbG8%3D
# http://www.youtube.com/watch?v=mHONNcZbwDY&pp=ygUFSGVsbG8%3D
# Hello! | Super Simple Songs
# /watch?v=tVlcKp3bWH8&pp=ygUFSGVsbG8%3D
# http://www.youtube.com/watch?v=tVlcKp3bWH8&pp=ygUFSGVsbG8%3D
# HELLO -  LIONEL RICHIE lyrics (HD)
# /watch?v=Axx9IMdL4jc&pp=ygUFSGVsbG8%3D
# http://www.youtube.com/watch?v=Axx9IMdL4jc&pp=ygUFSGVsbG8%3D
# Martin Solveig & Dragonette - Hello (Official Short Video Version HD)
# /watch?v=kK42LZqO0wA&pp=ygUFSGVsbG8%3D
# http://www.youtube.com/watch?v=kK42LZqO0wA&pp=ygUFSGVsbG8%3D
# Pop Smoke - Hello (Audio) ft. A Boogie wit da Hoodie
# /watch?v=fazMSCZg-mw&pp=ygUFSGVsbG8%3D
# http://www.youtube.com/watch?v=fazMSCZg-mw&pp=ygUFSGVsbG8%3D
# TREASURE - ‘HELLO’ M/V
# /watch?v=aPd9exmH17o&pp=ygUFSGVsbG8%3D
# http://www.youtube.com/watch?v=aPd9exmH17o&pp=ygUFSGVsbG8%3D
# Conkarah & Rosie Delmah - Hello (Reggae Cover) [Official Video]
# /watch?v=t071Wm45qWM&pp=ygUFSGVsbG8%3D
# http://www.youtube.com/watch?v=t071Wm45qWM&pp=ygUFSGVsbG8%3D
# Baby Rich - HELLO (ft. DDG) (Official Music Video)
# /watch?v=RPVOr8xGaXk&pp=ygUFSGVsbG8%3D
# http://www.youtube.com/watch?v=RPVOr8xGaXk&pp=ygUFSGVsbG8%3D

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mtcnn
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 39.9 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.9/dist-packages (from mtcnn) (4.7.0.72)
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from mtcnn) (2.12.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.9/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.22.4)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt

# %%
filename='/content/th.jpg'
img=plt.imread(filename)
plt.imshow(img)

# %%
detector=MTCNN()
faces=detector.detect_faces(img)
for face in faces:
   print(face)
# Out:
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 14/14 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 31ms/step
# {'box': [397, 46, 19, 26], 'confidence': 0.9999957084655762, 'keypoints': {'left_eye': (398, 56), 'right_eye': (403, 55), 'nose': (397, 61), 'mouth_left': (399, 66), 'mouth_right': (404, 66)}}
# {'box': [204, 42, 23, 32], 'confidence': 0.9999923706054688, 'keypoints': {'left_eye': (214, 51), 'right_eye': (224, 53), 'nose': (220, 57), 'mouth_left': (212, 63), 'mouth_right': (222, 65)}}
# {'box': [29, 24, 21, 28], 'confidence': 0.9999874830245972, 'keypoints': {'left_eye': (36, 35), 'right_eye': (46, 35), 'nose': (43, 41), 'mouth_left': (37, 46), 'mouth_right': (47, 45)}}
# {'box': [241, 21, 20, 26], 'confidence': 0.9999840259552002, 'keypoints': {'left_eye': (244, 30), 'right_eye': (253, 30), 'nose': (246, 33), 'mouth_left': (244, 40), 'mouth_right': (251, 40)}}
# {'box': [339, 77, 25, 34], 'confidence': 0.9999643564224243, 'keypoints': {'left_eye': (341, 91), 'right_eye': (349, 89), 'nose': (343, 97), 'mouth_left': (344, 104), 'mouth_right': (353, 102)}}
# {'box': [223, 118, 26, 37], 'confidence': 0.9998596906661987, 'keypoints': {'left_eye': (231, 133), 'right_eye': (243, 133), 'nose': (237, 141), 'mouth_left': (230, 145), 'mouth_right': (242, 145)}}
# {'box': [118, 104, 26, 38], 'confidence': 0.9998273253440857, 'keypoints': {'left_eye': (134, 118), 'right_eye': (142, 119), 'nose': (142, 128), 'mouth_left': (130, 134), 'mouth_right': (137, 134)}}
# {'box': [264, 36, 25, 33], 'confidence': 0.9998264908790588, 'keypoints': {'left_eye': (269, 48), 'right_eye': (280, 49), 'nose': (273, 56), 'mouth_left': (269, 61), 'mouth_right': (280, 61)}}
# {'box': [299, 69, 24, 33], 'confidence': 0.999363362789154, 'keypoints': {'left_eye': (303, 81), 'right_eye': (314, 80), 'nose': (309, 88), 'mouth_left': (305, 93), 'mouth_right': (316, 92)}}
# {'box': [97, 22, 21, 27], 'confidence': 0.9992839694023132, 'keypoints': {'left_eye': (107, 31), 'right_eye': (116, 30), 'nose': (115, 36), 'mouth_left': (108, 42), 'mouth_right': (116, 41)}}
# {'box': [160, 79, 24, 33], 'confidence': 0.9992269277572632, 'keypoints': {'left_eye': (170, 90), 'right_eye': (181, 90), 'nose': (178, 98), 'mouth_left': (169, 103), 'mouth_right': (179, 103)}}
# {'box': [377, 88, 31, 40], 'confidence': 0.9992115497589111, 'keypoints': {'left_eye': (384, 105), 'right_eye': (397, 102), 'nose': (391, 112), 'mouth_left': (388, 119), 'mouth_right': (401, 115)}}
# {'box': [132, 88, 27, 36], 'confidence': 0.9032008647918701, 'keypoints': {'left_eye': (145, 102), 'right_eye': (154, 103), 'nose': (153, 112), 'mouth_left': (141, 115), 'mouth_right': (150, 116)}}

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt
filename='/content/th.jpg'
img=plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(img)
plt.imshow(img)
ax=plt.gca()
for face in faces:
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
  for key,value in face['keypoints'].items():
    dot=plt.Circle(value,radius=2,color='red')
    ax.add_patch(dot)
  plt.savefig('/content/drive/MyDrive/Colab Notebooks/AI _ Nguyen Tien Dat/21 4')
plt.show()
# Out:
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 14/14 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 6ms/step

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt
def draw_faces(filename,result_list):
    data=plt.imread(filename)
    for i in range(len(result_list)):
      x1,y1,width,height=result_list[i]['box']
      x2,y2=x1+width,height
      plt.subplot(1,len(result_list),i+1)
      plt.axis('off')
      plt.imshow(data[y1:y2,x1:x2])
    plt.show()

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt
filename=('/content/drive/MyDrive/Colab Notebooks/AI _ Nguyen Tien Dat/21 4')
img=plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(img)
draw_face(filename,faces)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-47-9f8d8aed670b> in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 filename=('/content/drive/MyDrive/Colab Notebooks/AI _ Nguyen Tien Dat/21 4')
# ----> 4 img=plt.imread(filename)
#       5 detector=MTCNN()
#       6 faces=detector.detect_faces(img)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in imread(fname, format)
#    2193 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2194 def imread(fname, format=None):
# -> 2195     return matplotlib.image.imread(fname, format)
#    2196
#    2197
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/image.py in imread(fname, format)
#    1561             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1562             )
# -> 1563     with img_open(fname) as image:
#    1564         return (_pil_png_to_float_array(image)
#    1565                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# /usr/local/lib/python3.9/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# IsADirectoryError: [Errno 21] Is a directory: '/content/drive/MyDrive/Colab Notebooks/AI _ Nguyen Tien Dat/21 4'

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/th (1).jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 2s 2s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step
# Predicted: [('n03935335', 'piggy_bank', 0.91549367), ('n04131690', 'saltshaker', 0.052061945), ('n04462240', 'toyshop', 0.010082221)]

# %%
from keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np


model = VGG19(weights='imagenet')

img_path = '/th (1).jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 0s 243ms/step
# Predicted: [('n04131690', 'saltshaker', 0.60460657), ('n03935335', 'piggy_bank', 0.21961269), ('n04462240', 'toyshop', 0.08893801)]

# %%
from keras.applications.vgg19 import VGG
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np


model = VGG19(weights='imagenet')

img_path = '/th (3).jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
